# %% [markdown]
# <a href="https://colab.research.google.com/github/meenakshimeenuzz21/DSA-Class-Notes/blob/main/Python_Data_Type_and_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(type(5 + 5.0))
# Out:
# <class 'float'>

# %%
print(str(5) + " apples")
# Out:
# 5 apples

# %%
print(len("Python Rocks!"))
# Out:
# 13

# %%
print(15 + 4)
print(15 - 4)
print(15 * 4)
print(15 / 4)
# Out:
# 19
# 11
# 60
# 3.75

# %%
print(15 // 4)
# Out:
# 3

# %%
print(17 % 5)
# Out:
# 2

# %%
print(3 ** 4)
# Out:
# 81

# %%
print(10 + 2 * 5)
# Out:
# 20

# %%
print(7 % 3 == 1)
# Out:
# True

# %%
result = 3 ** 2 + 1
print(type(result))
# Out:
# <class 'int'>

# %%
print(8 // 3 == 2)
# Out:
# True

# %%
print(len("car") == 3)
# Out:
# True

# %%
print("Python" != "python")
# Out:
# True

# %%
print(type("10") == type(10))
# Out:
# False

# %%
print(None == False)
# Out:
# False

# %%
print(10 >= 10)
# Out:
# True

# %%
num = 15
print(num >= 10 and num <= 20)
# Out:
# True

# %%
text = "1234567890"
length = len(text)

print(length)
print(length % 2 == 0)
# Out:
# 10
# True

# %%
email = "example@gmail.com"

print("@" in email and "." in email)
# Out:
# True

# %%
print(type(len("hello")) == int)
# Out:
# True
