# %% [markdown]
# <a href="https://colab.research.google.com/github/meenakshimeenuzz21/DSA-Class-Notes/blob/main/Python_Practice_Qns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Welcome Message**

# %%
name = input("Enter your name: ")
print("Welcome to Data Analytics,", name + "!")
# Out:
# Enter your name: Meenakshi
# Welcome to Data Analytics, Meenakshi!

# %% [markdown]
# **2. Favorite Snack**

# %%
favorite_snack = "Chips"
print("I love munching on", favorite_snack, "during meetings!")
# Out:
# I love munching on Chips during meetings!

# %% [markdown]
# **3. Team Productivity**

# %%
tasks = 15
next_week = tasks * 2
print("Expected tasks next week:", next_week)
# Out:
# Expected tasks next week: 30

# %% [markdown]
# **4. Monthly Budget**

# %%
income = 30000
expenses = 20000
savings = income - expenses
print("Monthly savings:", savings)
# Out:
# Monthly savings: 10000

# %% [markdown]
# **5. Movie Night**

# %%
friends = 10
popcorn_per_friend = 1
total_popcorn = friends * popcorn_per_friend
print("Total popcorn bags needed:", total_popcorn)
# Out:
# Total popcorn bags needed: 10

# %% [markdown]
# **6. Product Review**

# %%
rating = int(input("Enter product rating (1-5): "))

if rating > 3:
    print("The product is above average!")
else:
    print("The product is average or below average.")
# Out:
# Enter product rating (1-5): 4
# The product is above average!

# %% [markdown]
# **7. Calculate Average Sales**

# %%
last_month = 50
this_month = 75
next_month = 100

average = (last_month + this_month + next_month) / 3
print("Average sales:", average)
# Out:
# Average sales: 75.0

# %% [markdown]
# **8. Simple Investment Return**

# %%
principal = 500
rate = 4
years = 3

interest = (principal * rate * years) / 100
total = principal + interest

print("Total amount:", total)
# Out:
# Total amount: 560.0

# %% [markdown]
# **9. Party Planning**

# %%
guests = 10
slices_per_guest = 1
slices_per_cake = 8

total_slices = guests * slices_per_guest
cakes = (total_slices + slices_per_cake - 1) // slices_per_cake

print("Cakes needed:", cakes)
# Out:
# Cakes needed: 2

# %% [markdown]
# **10. Text Analysis**

# %%
text = "Data Analytics"

if len(text) > 10:
    print("Wow! This text has more than 10 characters.")
else:
    print("This text has 10 or fewer characters.")
# Out:
# Wow! This text has more than 10 characters.

# %% [markdown]
# **11. Best Selling Product**

# %%
product_A_sales = 250
product_B_sales = 300

if product_A_sales > product_B_sales:
    print("Product A sold more.")
else:
    print("Product B sold more.")
# Out:
# Product B sold more.

# %% [markdown]
# **12. Scholarship Percentage**

# %%
scholarship = 750
total = 1000

percentage = (scholarship / total) * 100

print("Scholarship percentage:", percentage, "%")
print("Congratulations!")
# Out:
# Scholarship percentage: 75.0 %
# Congratulations!

# %% [markdown]
# **13. Variable Assignment**

# %%
favorite_color = "Blue"
print(favorite_color)
# Out:
# Blue

# %% [markdown]
# **14. Basic Arithmetic**

# %%
a = 10
b = 20

sum = a + b
print("Sum:", sum)
# Out:
# Sum: 30

# %% [markdown]
# **15. Area of a Rectangle**

# %%
length = 10
width = 5

area = length * width
print("Area of rectangle:", area)
# Out:
# Area of rectangle: 50

# %% [markdown]
# **16. Even or Odd**

# %%
num = 15

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %% [markdown]
# **17. Calculate Average**

# %%
a = 10
b = 20
c = 30

average = (a + b + c) / 3
print("Average:", average)
# Out:
# Average: 20.0

# %% [markdown]
# **18. Area of a Circle**

# %%
import math

radius = 7
area = math.pi * radius ** 2

print("Area of circle:", area)
# Out:
# Area of circle: 153.93804002589985

# %% [markdown]
# **19. Check String Length**

# %%
text = "Python"

if len(text) > 6:
    print("The string has more than 6 characters.")
else:
    print("The string does not have more than 6 characters.")
# Out:
# The string does not have more than 6 characters.

# %% [markdown]
# **20. Find Maximum of Two Numbers**

# %%
num1 = 15
num2 = 25

if num1 > num2:
    print("Maximum:", num1)
else:
    print("Maximum:", num2)
# Out:
# Maximum: 25

# %% [markdown]
# **21. Calculate Percentage**

# %%
total_marks = 500
obtained_marks = 400

percentage = (obtained_marks / total_marks) * 100

print("Percentage:", percentage, "%")
# Out:
# Percentage: 80.0 %
